# %%
with open('/Users/nitanshjain/Documents/Projects/bioinformatics/Hidden Messages Dataset.txt') as f:
    genome = f.read().strip()
print(genome)
text = genome.splitlines()
genome = text[0]
string_to_find = text[1]
# Out:
# ...
# AGGTCAGAG

# %%
count = 0
for i in range(len(genome) - len(string_to_find) + 1):
    if genome[i:i+len(string_to_find)] == string_to_find:
        count += 1
print(count)
# Out:
# 26

# %%
with open('/Users/nitanshjain/Documents/Projects/bioinformatics/Vibrio_cholerae.txt') as f:
    genome = f.read().strip()
text = genome.splitlines()
genome = text[0]
pattern_input = 'ATGATCAAG'

# %%
output = ''
for i in range(len(genome) - len(pattern_input) + 1):
    if genome[i:i+len(pattern_input)] == pattern_input:
        output += str(i) + ' '

# %%
with open('sample_2_output.txt', 'w') as f:
    f.write(output.strip())
